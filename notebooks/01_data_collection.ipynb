# %% [markdown]
# # Phase 2: Data Collection
# This notebook demonstrates fetching data using our `src.data_loader` module.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.data_loader import StockDataLoader

TICKERS = ['TCS.NS', 'HDFCBANK.NS', 'RELIANCE.NS']
loader = StockDataLoader(TICKERS, '2021-01-01', '2025-12-31', '../data/raw')
data = loader.fetch_and_save()
print('Data fetched successfully!')
